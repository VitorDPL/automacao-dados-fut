# %%
import pandas as pd

# %%
dados = pd.read_excel("dados.xlsx")

dados
# Out:
#          TIME CASA    TIME FORA  GOLS CASA  GOLS FORA  CHUTES GOL CASA  \
# 0     Vila Nova-GO        Sport          2          0                5
# 1    Novorizontino   América-MG          1          1                2
# 2      Ponte Preta        Goiás          1          1                6
# 3          Man Utd       Fulham          1          0                5
# 4       Las Palmas      Sevilla          2          2                5
# ..             ...          ...        ...        ...              ...
# 601    Aston Villa       Bayern          1          0                2
# 602     Sturm Graz  Club Brugge          0          1                1
# 603        Benfica   Atl Madrid          4          0               10
# 604      Liverpool      Bolonha          2          0                4
# 605     RB Leipzig     Juventus          2          3                7
#
#      CHUTES GOL FORA  FINALIZAÇÕES CASA  FINALIZAÇÕES FORA  \
# 0                  2                 11                  7
# 1                  1                  8                  9
# 2                  2                 22                 11
# 3                  2                 14                 10
# 4                  5                 15                 18
# ..               ...                ...                ...
# 601                7                  5                 17
# 602                4                  8                 13
# 603                0                 19                  4
# 604                2                  9                 12
# 605                5                 24                 16
#
#      CARTÃO AMARELO CASA  CARTÃO AMARELO FORA  ...  FALTAS CASA  FALTAS FORA  \
# 0                      3                    1  ...           22           10
# 1                      4                    3  ...           12           10
# 2                      3                    3  ...           12           18
# 3                      2                    3  ...           12           10
# 4                      2                    2  ...           14           15
# ..                   ...                  ...  ...          ...          ...
# 601                    3                    2  ...            8           12
# 602                    5                    1  ...           14           13
# 603                    1                    4  ...            6            8
# 604                    4                    2  ...           10            8
# 605                    1                    2  ...            4           14
#
#      POSSE BOLA CASA  POSSE BOLA FORA ESTÁDIO  \
# 0              38.4%            61.6%     NaN
# 1              32.5%            67.5%     NaN
# 2              63.3%            36.7%     NaN
# 3              55.4%            44.6%     NaN
# 4                48%              52%     NaN
# ..               ...              ...     ...
# 601              30%              70%     NaN
# 602            38.2%            61.8%     NaN
# 603            53.3%            46.7%     NaN
# 604            51.4%            48.6%     NaN
# 605            44.9%            55.1%     NaN
#
#                                       CAMPEONATO  CARTAO AMARELO CASA  \
# 0                        2024 Brasileiro Serie B                  NaN
# 1                        2024 Brasileiro Serie B                  NaN
# 2                        2024 Brasileiro Serie B                  NaN
# 3                 2024-25 English Premier League                  NaN
# 4                                 2024-25 LALIGA                  NaN
# ..                                           ...                  ...
# 601  2024-25 UEFA Champions League, League Phase                  NaN
# 602  2024-25 UEFA Champions League, League Phase                  NaN
# 603  2024-25 UEFA Champions League, League Phase                  NaN
# 604  2024-25 UEFA Champions League, League Phase                  NaN
# 605  2024-25 UEFA Champions League, League Phase                  NaN
#
#     CARTAO AMARELO FORA                            ESTADIO        DATA
# 0                   NaN        Onésio Brasileiro Alvarenga  16/08/2024
# 1                   NaN  Estádio Dr. Jorge Ismael de Biasi  16/08/2024
# 2                   NaN                   Moisés Lucarelli  16/08/2024
# 3                   NaN                       Old Trafford  16/08/2024
# 4                   NaN               Estadio Gran Canaria  16/08/2024
# ..                  ...                                ...         ...
# 601                 NaN                         Villa Park  02/10/2024
# 602                 NaN                     28 Black Arena  02/10/2024
# 603                 NaN                     Estádio da Luz  02/10/2024
# 604                 NaN                            Anfield  02/10/2024
# 605                 NaN                     Red Bull Arena  02/10/2024
#
# [606 rows x 22 columns]

# %% [markdown]
# ### Funções

# %%
def extrai_dados(time):
    return dados[(dados["TIME CASA"] == time) | (dados["TIME FORA"] == time)]

def filtra_dados(time, tipo_de_dado):
    tipo_de_dado = tipo_de_dado.upper()
    
    casa_df = pd.DataFrame(columns=["TIME CASA", "TIME FORA", f"{tipo_de_dado} CASA", f"{tipo_de_dado} FORA"])
    fora_df = pd.DataFrame(columns=["TIME CASA", "TIME FORA", f"{tipo_de_dado} CASA", f"{tipo_de_dado} FORA"])
    
    for indice, linha in dados.iterrows():
        if linha["TIME CASA"] == time:
            casa_df = pd.concat([casa_df, pd.DataFrame([linha])], ignore_index=True)
        elif linha["TIME FORA"] == time:
            fora_df = pd.concat([fora_df, pd.DataFrame([linha])], ignore_index=True)
    
    return (
        casa_df[["TIME CASA", "TIME FORA", f"{tipo_de_dado} CASA", f"{tipo_de_dado} FORA", "CAMPEONATO"]],
        fora_df[["TIME CASA", "TIME FORA", f"{tipo_de_dado} CASA", f"{tipo_de_dado} FORA", "CAMPEONATO"]]
    )

def exibe_dados(time, tipo_de_dado):
    casa, fora = filtra_dados(time, tipo_de_dado)
    if casa.empty:
        print(f"Nenhum dado encontrado para {time} como time casa.")
    else:
        display(casa)
    
    if fora.empty:
        print(f"Nenhum dado encontrado para {time} como time fora.")
    else:
        display(fora)

def media_dados_time(time, tipo_de_dado):
    tipo_de_dado = tipo_de_dado.upper()
    
    casa, fora = filtra_dados(time, tipo_de_dado)
    
    soma_casa = int(0)
    soma_fora = int(0)
    soma_geral = int(0)
    
    for indice, linha in casa.iterrows():
        soma_casa += linha[f"{tipo_de_dado} CASA"]

    for indice, linha in fora.iterrows():
        soma_fora += linha[f"{tipo_de_dado} FORA"]
    
    soma_geral = soma_casa + soma_fora

    media_casa = soma_casa / casa.shape[0]
    media_fora = soma_fora / fora.shape[0]
    media_geral = soma_geral / (casa.shape[0] + fora.shape[0])

    print(
        f"===========- DADOS {tipo_de_dado} {time} -===========\n"
        f"Média {tipo_de_dado} jogando em casa: {media_casa:.2f}\n"
        f"Média {tipo_de_dado} jogando fora: {media_fora:.2f}\n"
        f"Média {tipo_de_dado} Geral ( casa e fora ): {media_geral:.2f}"
    )
        
    return media_casa, media_fora, media_geral

def resultados(time, tipo_de_dado):
    exibe_dados(time, tipo_de_dado)
    media_dados_time(time, tipo_de_dado)

# %% [markdown]
# # Times

# %%
time_casa = "Operario PR"
time_fora = "Chapecoense"

# %% [markdown]
# # Finalizações

# %% [markdown]
# ## Time casa:

# %%
resultados(time_casa, "finalizações")
# Out:
#      TIME CASA     TIME FORA FINALIZAÇÕES CASA FINALIZAÇÕES FORA  \
# 0  Operario PR  Vila Nova-GO                11                10
# 1  Operario PR       Brusque                18                 6
# 2  Operario PR      Coritiba                16                 8
# 3  Operario PR       Guarani                17                10
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
#      TIME CASA    TIME FORA FINALIZAÇÕES CASA FINALIZAÇÕES FORA  \
# 0  Ponte Preta  Operario PR                 8                11
# 1        Ceará  Operario PR                14                18
# 2     Amazonas  Operario PR                16                10
# 3       Santos  Operario PR                17                 8
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
# ===========- DADOS FINALIZAÇÕES Operario PR -===========
# Média FINALIZAÇÕES jogando em casa: 15.50
# Média FINALIZAÇÕES jogando fora: 11.75
# Média FINALIZAÇÕES Geral ( casa e fora ): 13.62

# %% [markdown]
# ## Time fora:

# %%
resultados(time_fora, "finalizações")
# Out:
#      TIME CASA    TIME FORA FINALIZAÇÕES CASA FINALIZAÇÕES FORA  \
# 0  Chapecoense      Guarani                11                15
# 1  Chapecoense          CRB                17                11
# 2  Chapecoense  Botafogo SP                13                13
# 3  Chapecoense        Ceará                 9                15
# 4  Chapecoense         Avaí                 8                14
# 5  Chapecoense     Amazonas                10                23
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
# 4  2024 Brasileiro Serie B
# 5  2024 Brasileiro Serie B
#       TIME CASA    TIME FORA FINALIZAÇÕES CASA FINALIZAÇÕES FORA  \
# 0    América-MG  Chapecoense                16                16
# 1   Ponte Preta  Chapecoense                16                10
# 2  Vila Nova-GO  Chapecoense                17                12
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# ===========- DADOS FINALIZAÇÕES Chapecoense -===========
# Média FINALIZAÇÕES jogando em casa: 11.33
# Média FINALIZAÇÕES jogando fora: 12.67
# Média FINALIZAÇÕES Geral ( casa e fora ): 11.78

# %% [markdown]
# # Chutes ao gol

# %% [markdown]
# ### Time casa:

# %%
resultados(time_casa, "Chutes gol")
# Out:
#      TIME CASA     TIME FORA CHUTES GOL CASA CHUTES GOL FORA  \
# 0  Operario PR  Vila Nova-GO               5               4
# 1  Operario PR       Brusque               4               1
# 2  Operario PR      Coritiba               5               4
# 3  Operario PR       Guarani               8               4
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
#      TIME CASA    TIME FORA CHUTES GOL CASA CHUTES GOL FORA  \
# 0  Ponte Preta  Operario PR               1               4
# 1        Ceará  Operario PR               7               7
# 2     Amazonas  Operario PR               6               2
# 3       Santos  Operario PR               7               1
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
# ===========- DADOS CHUTES GOL Operario PR -===========
# Média CHUTES GOL jogando em casa: 5.50
# Média CHUTES GOL jogando fora: 3.50
# Média CHUTES GOL Geral ( casa e fora ): 4.50

# %% [markdown]
# ### Time fora:

# %%
resultados(time_fora, "Chutes gol")
# Out:
#      TIME CASA    TIME FORA CHUTES GOL CASA CHUTES GOL FORA  \
# 0  Chapecoense      Guarani               4               6
# 1  Chapecoense          CRB               4               3
# 2  Chapecoense  Botafogo SP               3               3
# 3  Chapecoense        Ceará               5               5
# 4  Chapecoense         Avaí               3               5
# 5  Chapecoense     Amazonas               6               5
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
# 4  2024 Brasileiro Serie B
# 5  2024 Brasileiro Serie B
#       TIME CASA    TIME FORA CHUTES GOL CASA CHUTES GOL FORA  \
# 0    América-MG  Chapecoense               6               8
# 1   Ponte Preta  Chapecoense               3               3
# 2  Vila Nova-GO  Chapecoense               7               5
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# ===========- DADOS CHUTES GOL Chapecoense -===========
# Média CHUTES GOL jogando em casa: 4.17
# Média CHUTES GOL jogando fora: 5.33
# Média CHUTES GOL Geral ( casa e fora ): 4.56

# %% [markdown]
# # Cartões

# %% [markdown]
# ### Time casa:

# %%
resultados(time_casa, "CARTÃO AMARELO")
# Out:
#      TIME CASA     TIME FORA CARTÃO AMARELO CASA CARTÃO AMARELO FORA  \
# 0  Operario PR  Vila Nova-GO                   4                   2
# 1  Operario PR       Brusque                   2                   5
# 2  Operario PR      Coritiba                   3                   3
# 3  Operario PR       Guarani                   2                   5
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
#      TIME CASA    TIME FORA CARTÃO AMARELO CASA CARTÃO AMARELO FORA  \
# 0  Ponte Preta  Operario PR                   3                   1
# 1        Ceará  Operario PR                   5                   5
# 2     Amazonas  Operario PR                   1                   2
# 3       Santos  Operario PR                   0                   1
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
# ===========- DADOS CARTÃO AMARELO Operario PR -===========
# Média CARTÃO AMARELO jogando em casa: 2.75
# Média CARTÃO AMARELO jogando fora: 2.25
# Média CARTÃO AMARELO Geral ( casa e fora ): 2.50

# %% [markdown]
# ### Time Fora

# %%
resultados(time_fora, "CARTÃO AMARELO")
# Out:
#      TIME CASA    TIME FORA CARTÃO AMARELO CASA CARTÃO AMARELO FORA  \
# 0  Chapecoense      Guarani                   3                   1
# 1  Chapecoense          CRB                   4                   7
# 2  Chapecoense  Botafogo SP                   4                   2
# 3  Chapecoense        Ceará                   6                   2
# 4  Chapecoense         Avaí                   4                   1
# 5  Chapecoense     Amazonas                   3                   3
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
# 4  2024 Brasileiro Serie B
# 5  2024 Brasileiro Serie B
#       TIME CASA    TIME FORA CARTÃO AMARELO CASA CARTÃO AMARELO FORA  \
# 0    América-MG  Chapecoense                   0                   0
# 1   Ponte Preta  Chapecoense                   3                   2
# 2  Vila Nova-GO  Chapecoense                   5                   3
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# ===========- DADOS CARTÃO AMARELO Chapecoense -===========
# Média CARTÃO AMARELO jogando em casa: 4.00
# Média CARTÃO AMARELO jogando fora: 1.67
# Média CARTÃO AMARELO Geral ( casa e fora ): 3.22

# %% [markdown]
# # Escanteios

# %% [markdown]
# ### Time Casa:

# %%
resultados(time_casa, "escanteios")
# Out:
#      TIME CASA     TIME FORA ESCANTEIOS CASA ESCANTEIOS FORA  \
# 0  Operario PR  Vila Nova-GO               3               5
# 1  Operario PR       Brusque               7               2
# 2  Operario PR      Coritiba               9               3
# 3  Operario PR       Guarani               7               7
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
#      TIME CASA    TIME FORA ESCANTEIOS CASA ESCANTEIOS FORA  \
# 0  Ponte Preta  Operario PR               3               4
# 1        Ceará  Operario PR               6               2
# 2     Amazonas  Operario PR               5               1
# 3       Santos  Operario PR              10               4
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
# ===========- DADOS ESCANTEIOS Operario PR -===========
# Média ESCANTEIOS jogando em casa: 6.50
# Média ESCANTEIOS jogando fora: 2.75
# Média ESCANTEIOS Geral ( casa e fora ): 4.62

# %% [markdown]
# ### Time Fora:

# %%
resultados(time_fora, "escanteios")
# Out:
#      TIME CASA    TIME FORA ESCANTEIOS CASA ESCANTEIOS FORA  \
# 0  Chapecoense      Guarani               7               3
# 1  Chapecoense          CRB               5               5
# 2  Chapecoense  Botafogo SP               6               5
# 3  Chapecoense        Ceará               4              10
# 4  Chapecoense         Avaí               3               8
# 5  Chapecoense     Amazonas               2               5
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# 3  2024 Brasileiro Serie B
# 4  2024 Brasileiro Serie B
# 5  2024 Brasileiro Serie B
#       TIME CASA    TIME FORA ESCANTEIOS CASA ESCANTEIOS FORA  \
# 0    América-MG  Chapecoense               7               6
# 1   Ponte Preta  Chapecoense               4               4
# 2  Vila Nova-GO  Chapecoense               8               2
#
#                 CAMPEONATO
# 0  2024 Brasileiro Serie B
# 1  2024 Brasileiro Serie B
# 2  2024 Brasileiro Serie B
# ===========- DADOS ESCANTEIOS Chapecoense -===========
# Média ESCANTEIOS jogando em casa: 4.50
# Média ESCANTEIOS jogando fora: 4.00
# Média ESCANTEIOS Geral ( casa e fora ): 4.33
